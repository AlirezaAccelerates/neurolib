# %%
import matplotlib.pyplot as plt
import numpy as np
import os

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'

# %%
# define plot function for later convenience
def plot_singlenode(model, duration, dt, state, target, control, input, weight_array=[], M=1):
    fig, ax = plt.subplots( 2,1, figsize=(8,4), constrained_layout=True)

    # Plot the target (dashed line) and unperturbed activity
    t_array = np.arange(0, duration+dt, dt)

    ax[0].plot(t_array, state[0,0,:], label="x", color=color_x, linewidth=1)
    ax[0].plot(t_array, state[0,1,:], label="y", color=color_y, linewidth=1)
    ax[0].plot(t_array, target[0,0,:], linestyle='dashed', label="Target x", color=color_x)
    ax[0].plot(t_array, target[0,1,:], linestyle='dashed', label="Target y", color=color_y)
    ax[0].legend(loc="upper left")
    ax[0].set_title("Stimulated activity and target activity")

    for m in range(M-1):
        model.run()
        state = np.concatenate((np.concatenate( (model.params["exc_init"], model.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (model.x, model.y), axis=1)), axis=2)
        ax[0].plot(t_array, state[0,0,:], label="x", color=color_x, linewidth=1)
        ax[0].plot(t_array, state[0,1,:], label="y", color=color_y, linewidth=1)

    # Plot the target control signal (dashed line) and "initial" zero control signal
    ax[1].plot(t_array, control[0,0,:], label="stimulation x", color=color_x)
    ax[1].plot(t_array, control[0,1,:], label="stimulation y", color=color_y)
    ax[1].plot(t_array, input[0,0,:], linestyle='dashed', label="input x", color=color_x)
    ax[1].plot(t_array, input[0,1,:], linestyle='dashed', label="input y", color=color_y)
    ax[1].legend(loc="upper left")
    ax[1].set_title("Active stimulation and input stimulation")

    #ax[2].plot(weight_array)
    #ax[2].set_title("Cost throughout optimization.")

    plt.show()

# %%
wc = WCModel()
wc.params.sigma_ou = 0.
wc.params.x_ou_mean = 0.
#wc.params.mu_inh = 5.
dt = 0.1

wc.params["dt"] = dt
duration = 120.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
background_input_osc = zero_input.copy()
background_input_osc += 0.8

wc.params["duration"] = duration
wc.run()

exc_init = np.array([[wc.exc[0,-1]]])
inh_init = np.array([[wc.inh[0,-1]]])
wc.params["exc_init"] = exc_init
wc.params["inh_init"] = inh_init
wc.run()

target = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

wc.params["exc_ext"] = zero_input + background_input_osc
wc.params["inh_ext"] = zero_input
wc.run()

exc_init_osc = np.array([[wc.exc[0,-1]]])
inh_init_osc = np.array([[wc.inh[0,-1]]])
wc.params["exc_init"] = exc_init_osc
wc.params["inh_init"] = inh_init_osc
wc.run()

state = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

plot_singlenode(wc, duration, dt, state, target, zero_control, zero_control)

# %%
wc.params["exc_ext"] = zero_input + background_input_osc
wc.params["inh_ext"] = zero_input
w2 = 1e-2
wp = 1.

printarray = np.concatenate( (np.arange(0,101,1), np.arange(200,1001,100)) )

#c_mat = np.zeros((1,2))
#c_mat[0,0] = 1

wc_controlled_noisefree = oc_wc.OcWc(wc, target, w_p=wp, w_2=w2,
            print_array=printarray,
            precision_cost_interval=(int(100/dt),None),
            #control_matrix=c_mat
            )

init_control = np.zeros((wc_controlled_noisefree.control.shape))
#init_control[0,0,int(100/dt):-1] = -0.5
wc_controlled_noisefree.control = init_control
wc_controlled_noisefree.update_input()

# We run 100 iterations of the optimal control gradient descent algorithm
wc_controlled_noisefree.optimize(100)

state = wc_controlled_noisefree.get_xs()
control_noisefree = wc_controlled_noisefree.control

plot_singlenode(wc_controlled_noisefree.model, duration, dt, state, target, control_noisefree, zero_control, wc_controlled_noisefree.cost_history)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.09518722395456827
# Cost in iteration 1: 0.08550280949343136
# Cost in iteration 2: 0.07993750610161329
# Cost in iteration 3: 0.04656882376546889
# Cost in iteration 4: 0.01628938215968204
# Cost in iteration 5: 0.013735874151728642
# Cost in iteration 6: 0.012900473326462297
# Cost in iteration 7: 0.012318334728857242
# Cost in iteration 8: 0.012056732736142219
# Cost in iteration 9: 0.01200982155630697
# Cost in iteration 10: 0.011981196219791525
# Cost in iteration 11: 0.011979109642578145
# Cost in iteration 12: 0.011956532613513673
# Cost in iteration 13: 0.011952685130444373
# Cost in iteration 14: 0.011945082136254798
# Cost in iteration 15: 0.011943146082335083
# Cost in iteration 16: 0.011940874446196983
# Cost in iteration 17: 0.011940133747055867
# Cost in iteration 18: 0.01193914278251829
# Cost in iteration 19: 0.011936839531548334
# Cost in iteration 20: 0.011936292631932539
# Cost in iteration 21: 0.01193491340868818
# Cost in iteration 22: 0.011934833565244989
# Cost in iteration 23: 0.011934631614818603
# Cost in iteration 24: 0.011934532257976627
# Cost in iteration 25: 0.011934404852961688
# Cost in iteration 26: 0.011934382865083158
# Cost in iteration 27: 0.011934284718262248
# Cost in iteration 28: 0.011934262055212499
# Cost in iteration 29: 0.011934254488015845
# Cost in iteration 30: 0.011934218925871303
# Cost in iteration 31: 0.011934213478618536
# Cost in iteration 32: 0.011934183377511037
# Cost in iteration 33: 0.01193417695619629
# Cost in iteration 34: 0.011934175497804886
# Cost in iteration 35: 0.0119341639218877
# Cost in iteration 36: 0.011934160040468753
# Cost in iteration 37: 0.011934158570603114
# Cost in iteration 38: 0.011934153256527056
# Cost in iteration 39: 0.011934152894159382
# Cost in iteration 40: 0.011934147417408426
# Cost in iteration 41: 0.01193414650306794
# Cost in iteration 42: 0.011934145063591708
# Cost in iteration 43: 0.011934144273097903
# Cost in iteration 44: 0.011934142838471835
# Cost in iteration 45: 0.011934142423495352
# Cost in iteration 46: 0.011934142325289717
# Cost in iteration 47: 0.011934141621647364
# Cost in iteration 48: 0.011934141381240982
# Cost in iteration 49: 0.01193414130513441
# Cost in iteration 50: 0.011934140947079926
# Cost in iteration 51: 0.011934140808705453
# Cost in iteration 52: 0.01193414075528499
# Cost in iteration 53: 0.01193414057300185
# Cost in iteration 54: 0.011934140493976095
# Cost in iteration 55: 0.011934140459672983
# Cost in iteration 56: 0.011934140365151604
# Cost in iteration 57: 0.011934140356671421
# Cost in iteration 58: 0.011934140250389238
# Cost in iteration 59: 0.011934140233396857
# Cost in iteration 60: 0.011934140203438033
# Cost in iteration 61: 0.01193414019165484
# Cost in iteration 62: 0.01193414015948338
# Cost in iteration 63: 0.011934140151925846
# Cost in iteration 64: 0.011934140151762623
# Cost in iteration 65: 0.011934140135117205
# Cost in iteration 66: 0.01193414013073811
# Cost in iteration 67: 0.011934140130246174
# Cost in iteration 68: 0.011934140121579239
# Cost in iteration 69: 0.011934140119053024
# Cost in iteration 70: 0.011934140118571145
# Cost in iteration 71: 0.011934140114055594
# Cost in iteration 72: 0.01193414011260481
# Cost in iteration 73: 0.011934140112233687
# Cost in iteration 74: 0.011934140109871802
# Cost in iteration 75: 0.011934140109041197
# Cost in iteration 76: 0.011934140108781455
# Cost in iteration 77: 0.011934140107544703
# Cost in iteration 78: 0.011934140107070588
# Cost in iteration 79: 0.011934140106899154
# Cost in iteration 80: 0.011934140106249777
# Cost in iteration 81: 0.011934140105979773
# Cost in iteration 82: 0.011934140105870504
# Cost in iteration 83: 0.011934140105529085
# Cost in iteration 84: 0.011934140105526075
# Cost in iteration 85: 0.011934140105132211
# Cost in iteration 86: 0.011934140105077352
# Cost in iteration 87: 0.011934140104967246
# Cost in iteration 88: 0.011934140104936434
# Cost in iteration 89: 0.011934140104814993
# Cost in iteration 90: 0.011934140104790207
# Cost in iteration 91: 0.011934140104754128
# Cost in iteration 92: 0.011934140104733563
# Cost in iteration 93: 0.011934140104695781
# Cost in iteration 94: 0.011934140104685177
# Cost in iteration 95: 0.011934140104683463
# Cost in iteration 96: 0.011934140104663676
# Cost in iteration 97: 0.011934140104657591
# Cost in iteration 98: 0.011934140104656174
# Cost in iteration 99: 0.011934140104645828
# Cost in iteration 100: 0.011934140104642336
# Final cost : 0.011934140104642336

# %%
wc_controlled_noisefree.optimize(500)

state = wc_controlled_noisefree.get_xs()
control_noisefree = wc_controlled_noisefree.control

plot_singlenode(wc_controlled_noisefree.model, duration, dt, state, target, control_noisefree, zero_control, wc_controlled_noisefree.cost_history)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.011934140104623417
# Cost in iteration 1: 0.011934140104623417
# Cost in iteration 2: 0.011934140104623417
# Cost in iteration 3: 0.011934140104623417
# Cost in iteration 4: 0.011934140104623417
# Cost in iteration 5: 0.011934140104623417
# Cost in iteration 6: 0.011934140104623417
# Cost in iteration 7: 0.011934140104623417
# Cost in iteration 8: 0.011934140104623417
# Cost in iteration 9: 0.011934140104623417
# Cost in iteration 10: 0.011934140104623417
# Cost in iteration 11: 0.011934140104623417
# Cost in iteration 12: 0.011934140104623417
# Cost in iteration 13: 0.011934140104623417
# Cost in iteration 14: 0.011934140104623417
# Cost in iteration 15: 0.011934140104623417
# Cost in iteration 16: 0.011934140104623417
# Cost in iteration 17: 0.011934140104623417
# Cost in iteration 18: 0.011934140104623417
# Cost in iteration 19: 0.011934140104623417
# Cost in iteration 20: 0.011934140104623417
# Cost in iteration 21: 0.011934140104623417
# Cost in iteration 22: 0.011934140104623417
# Cost in iteration 23: 0.011934140104623417
# Cost in iteration 24: 0.011934140104623417
# Cost in iteration 25: 0.011934140104623417
# Cost in iteration 26: 0.011934140104623417
# Cost in iteration 27: 0.011934140104623417
# Cost in iteration 28: 0.011934140104623417
# Cost in iteration 29: 0.011934140104623417
# Cost in iteration 30: 0.011934140104623417
# Cost in iteration 31: 0.011934140104623417
# Cost in iteration 32: 0.011934140104623417
# Cost in iteration 33: 0.011934140104623417
# Cost in iteration 34: 0.011934140104623417
# Cost in iteration 35: 0.011934140104623417
# Cost in iteration 36: 0.011934140104623417
# Cost in iteration 37: 0.011934140104623417
# Cost in iteration 38: 0.011934140104623417
# Cost in iteration 39: 0.011934140104623417
# Cost in iteration 40: 0.011934140104623417
# Cost in iteration 41: 0.011934140104623417
# Cost in iteration 42: 0.011934140104623417
# Cost in iteration 43: 0.011934140104623417
# Cost in iteration 44: 0.011934140104623417
# Cost in iteration 45: 0.011934140104623417
# Cost in iteration 46: 0.011934140104623417
# Cost in iteration 47: 0.011934140104623417
# Cost in iteration 48: 0.011934140104623417
# Cost in iteration 49: 0.011934140104623417
# Cost in iteration 50: 0.011934140104623417
# Cost in iteration 51: 0.011934140104623417
# Cost in iteration 52: 0.011934140104623417
# Cost in iteration 53: 0.011934140104623417
# Cost in iteration 54: 0.011934140104623417
# Cost in iteration 55: 0.011934140104623417
# Cost in iteration 56: 0.011934140104623417
# Cost in iteration 57: 0.011934140104623417
# Cost in iteration 58: 0.011934140104623417
# Cost in iteration 59: 0.011934140104623417
# Cost in iteration 60: 0.011934140104623417
# Cost in iteration 61: 0.011934140104623417
# Cost in iteration 62: 0.011934140104623417
# Cost in iteration 63: 0.011934140104623417
# Cost in iteration 64: 0.011934140104623417
# Cost in iteration 65: 0.011934140104623417
# Cost in iteration 66: 0.011934140104623417
# Cost in iteration 67: 0.011934140104623417
# Cost in iteration 68: 0.011934140104623417
# Cost in iteration 69: 0.011934140104623417
# Cost in iteration 70: 0.011934140104623417
# Cost in iteration 71: 0.011934140104623417
# Cost in iteration 72: 0.011934140104623417
# Cost in iteration 73: 0.011934140104623417
# Cost in iteration 74: 0.011934140104623417
# Cost in iteration 75: 0.011934140104623417
# Cost in iteration 76: 0.011934140104623417
# Cost in iteration 77: 0.011934140104623417
# Cost in iteration 78: 0.011934140104623417
# Cost in iteration 79: 0.011934140104623417
# Cost in iteration 80: 0.011934140104623417
# Cost in iteration 81: 0.011934140104623417
# Cost in iteration 82: 0.011934140104623417
# Cost in iteration 83: 0.011934140104623417
# Cost in iteration 84: 0.011934140104623417
# Cost in iteration 85: 0.011934140104623417
# Cost in iteration 86: 0.011934140104623417
# Cost in iteration 87: 0.011934140104623417
# Cost in iteration 88: 0.011934140104623417
# Cost in iteration 89: 0.011934140104623417
# Cost in iteration 90: 0.011934140104623417
# Cost in iteration 91: 0.011934140104623417
# Cost in iteration 92: 0.011934140104623417
# Cost in iteration 93: 0.011934140104623417
# Cost in iteration 94: 0.011934140104623417
# Cost in iteration 95: 0.011934140104623417
# Cost in iteration 96: 0.011934140104623417
# Cost in iteration 97: 0.011934140104623417
# Cost in iteration 98: 0.011934140104623417
# Cost in iteration 99: 0.011934140104623417
# Cost in iteration 100: 0.011934140104623417
# Cost in iteration 200: 0.011934140104623417
# Cost in iteration 300: 0.011934140104623417
# Cost in iteration 400: 0.011934140104623417
# Cost in iteration 500: 0.011934140104623417
# Final cost : 0.011934140104623417

# %%
sigma_array = [1. * 1e-3, 5. * 1e-3]
M_array = [4,20,100]

weights = np.zeros(( len(sigma_array) ))
controls = [ [None, None, None], [None, None, None] ]
costs_history = [ [None, None, None], [None, None, None] ]
costs = np.zeros(( len(sigma_array), len(M_array)+1 ))

# %%
wc_noise = WCModel()
wc_noise.params.sigma_ou = 0.
wc_noise.params.x_ou_mean = 0.

# %%
wc_noise.params.duration = 1. * 1e6
wc_noise.params["exc_init"] = np.array([[exc_init]])
wc_noise.params["inh_init"] = np.array([[inh_init]])
wc_noise.params["exc_ext"] = zero_input
wc_noise.params["inh_ext"] = zero_input

for i_s in range(len(sigma_array)):
    wc_noise.params.sigma_ou = sigma_array[i_s]

    wc_noise.run()
    weights[i_s] = 1. / (np.std(wc_noise.exc[0,100:]) + np.std(wc_noise.inh[0,100:]) )

print(weights)
# Out:
# [361.41056396  72.16476053]

# %%
wc_noise.params.duration = duration
wc_noise.params["exc_init"] = exc_init_osc
wc_noise.params["inh_init"] = inh_init_osc

M_val = 500
max_iterations = 50
wc_noise.run()
printarray = np.concatenate( (np.arange(0,100,10), np.arange(0,2001,100)) )

costs_history = [ [None, None, None, None], [None, None, None, None], [None, None, None, None] ]

for i_s in range(len(sigma_array)):
    for i_m in range(len(M_array)):

        if i_m in []:
            continue

        if i_s in []:
            continue

        if type(costs_history[i_s][i_m]) != type(None):
            continue

        print("--------------------------------------------------------------")
        print("---------------------------- sigma, M = ", sigma_array[i_s], M_array[i_m])

        wc_noise.params["exc_ext"] = zero_input + background_input_osc
        wc_noise.params["inh_ext"] = zero_input
        wc_noise.params.sigma_ou = sigma_array[i_s]

        wc_controlled_models = oc_wc.OcWc(wc_noise, target, w_p=wp, w_2=w2, print_array=printarray, precision_cost_interval=[1000,None],
                                    #control_matrix=c_mat,
                                    M=int(M_array[i_m]),
                                    #M = 10,
                                    M_validation=M_val, validate_per_step=True)

        wc_controlled_models.step = 10.

        # We run 100 iterations of the optimal control gradient descent algorithm
        wc_controlled_models.optimize(max_iterations)

        state = wc_controlled_models.get_xs()
        controls[i_s][i_m] = wc_controlled_models.control
        costs_history[i_s][i_m] = wc_controlled_models.cost_history
        costs[i_s][i_m+1] = wc_controlled_models.cost_validation

        # plot_singlenode(wc_controlled_models.model, duration, dt, state, target, controls[i_s][i_m], zero_control, wc_controlled_models.cost_history, M=10)
# Out:
# --------------------------------------------------------------
# ---------------------------- sigma, M =  0.001 4
# Compute control for a noisy system
# Mean cost in iteration 0: 0.09672142705574661
# Mean cost in iteration 10: 0.016239854880959654
# Mean cost in iteration 20: 0.012943067021808814
# Mean cost in iteration 30: 0.012432411183607014
# Mean cost in iteration 40: 0.012182249514830462
# Mean cost in iteration 50: 0.012119773955476327
# Minimal cost found at iteration 47
# Final cost validated with 500 noise realizations : 0.012226121361897723
# --------------------------------------------------------------
# ---------------------------- sigma, M =  0.001 20
# Compute control for a noisy system
# Mean cost in iteration 0: 0.09610205780355713
# Mean cost in iteration 10: 0.015102657737517743
# Mean cost in iteration 20: 0.012517771998138503
# Mean cost in iteration 30: 0.012194621693385314
# Mean cost in iteration 40: 0.012141574036402304
# Mean cost in iteration 50: 0.012128751493706198
# Minimal cost found at iteration 39
# Final cost validated with 500 noise realizations : 0.012217323061130873
# --------------------------------------------------------------
# ---------------------------- sigma, M =  0.001 100
# Compute control for a noisy system
# Mean cost in iteration 0: 0.09828186924380572
# Mean cost in iteration 10: 0.01478029765356248
# Mean cost in iteration 20: 0.012422657888594764
# Mean cost in iteration 30: 0.012225935381336204
# Mean cost in iteration 40: 0.012139426711824695
# Mean cost in iteration 50: 0.012257492538966262
# Minimal cost found at iteration 39
# Final cost validated with 500 noise realizations : 0.012081506585536968
# --------------------------------------------------------------
# ---------------------------- sigma, M =  0.005 4
# Compute control for a noisy system
# Mean cost in iteration 0: 0.1271007517061613
# Mean cost in iteration 10: 0.0222291480698975
# Mean cost in iteration 20: 0.018004564753961512
# Mean cost in iteration 30: 0.016851087873426925
# Mean cost in iteration 40: 0.01706362092592682
# Mean cost in iteration 50: 0.01707681002349412
# Minimal cost found at iteration 49
# Final cost validated with 500 noise realizations : 0.017313805805524045
# --------------------------------------------------------------
# ---------------------------- sigma, M =  0.005 20
# Compute control for a noisy system
# Mean cost in iteration 0: 0.11958944645325979
# Mean cost in iteration 10: 0.018435583114066314
# Mean cost in iteration 20: 0.016903706700320608
# Mean cost in iteration 30: 0.017090006757165082
# Mean cost in iteration 40: 0.01625268802509296
# Mean cost in iteration 50: 0.016766884611351746
# Minimal cost found at iteration 40
# Final cost validated with 500 noise realizations : 0.016028042132241113
# --------------------------------------------------------------
# ---------------------------- sigma, M =  0.005 100
# Compute control for a noisy system
# Mean cost in iteration 0: 0.12750982611772416
# Mean cost in iteration 10: 0.01777016803516191
# Mean cost in iteration 20: 0.016833798650131373
# Mean cost in iteration 30: 0.016633167563465966
# Mean cost in iteration 40: 0.016658100456975654
# Mean cost in iteration 50: 0.016599802451284732
# Minimal cost found at iteration 39
# Final cost validated with 500 noise realizations : 0.016289119164115188

# %%
wc_plot = WCModel()

wc_plot.params["duration"] = duration
wc_plot.params["exc_init"] = exc_init_osc
wc_plot.params["inh_init"] = inh_init_osc

# %%
for i_s in range(len(sigma_array)):

    print(i_s)

    wc_plot.params.sigma_ou = sigma_array[i_s]

    wc_plot.params["exc_ext"] = control_noisefree[:,0,:] + background_input_osc
    wc_plot.params["inh_ext"] = control_noisefree[:,1,:]

    cost_validation = 0.0
    energy_cost = cost_functions.energy_cost(wc_plot.params.dt, control_noisefree, w_2=w2)

    for m in range(M_val):
        wc_plot.run()
        state = np.concatenate((np.concatenate( (wc_plot.params["exc_init"], wc_plot.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc_plot.exc, wc_plot.inh), axis=1)), axis=2)
        precision_cost = cost_functions.precision_cost(wc_plot.params.dt, target, state, wp, np.ones( (1, 2)), (1000,1201))
        cost_validation += precision_cost

    costs[i_s][0] =  energy_cost + cost_validation/M_val

print(costs[0][0], costs[1][0])
# Out:
# 0
# 1
# 0.012212359211347182 0.02107907583985036

# %%
row, col = int(2*len(sigma_array)), int(len(M_array)+1)

fig = plt.figure(figsize=(4*col,2*row))
gs = fig.add_gridspec(row, col, hspace=0.1, wspace=0)
ax = gs.subplots(sharex='col')
box_props = dict(boxstyle='round', facecolor='white', alpha=0.8)
fs = 14
savepath = ('..' + os.sep + '..' + os.sep + '..' + os.sep + 'Talks_Conf_Workshops_Schools' +
            os.sep + '22' + os.sep + '2022_10_groupTalk' + os.sep + 'talk' + os.sep + 'images')

time_array = np.arange(0, duration+dt, dt)

for i_s in range(len(sigma_array)):
    ax[2*i_s, 0].text(-0.1, 0.3, r'$\sigma = $'+ "{}".format(sigma_array[i_s]),
    transform=ax[2*i_s, 0].transAxes, rotation='vertical', fontsize=fs)

    ax[2*i_s + 1, 0].plot(time_array, control_noisefree[0,0,:], color=color_x)
    ax[2*i_s + 1, 0].plot(time_array, control_noisefree[0,1,:], color=color_y)
    
    wc_plot.params.sigma_ou = sigma_array[i_s]

    wc_plot.params["x_ext"] = control_noisefree[:,0,:] + background_input_osc
    wc_plot.params["y_ext"] = control_noisefree[:,1,:]

    ax[2*i_s, 0].plot(time_array[1:], target[0,0,1:], color=color_x, linewidth=1, linestyle='--')
    ax[2*i_s, 0].plot(time_array[1:], target[0,1,1:], color=color_y, linewidth=1, linestyle='--')

    for m in range(10):
        wc_plot.run()
        ax[2*i_s, 0].plot(time_array[1:], wc_plot.exc[0,:], color=color_x, linewidth=1)
        ax[2*i_s, 0].plot(time_array[1:], wc_plot.inh[0,:], color=color_y, linewidth=1)

    ax[2*i_s, 0].text(0.04,0.1, r'$\mathcal{F} = $' + "{:.3f}".format(costs[i_s][0]),
        transform=ax[2*i_s, 0].transAxes, fontsize=fs, bbox=box_props)

    for i_m in range(len(M_array)):
        ax[2*i_s + 1, i_m+1].plot(time_array, controls[i_s][i_m][0,0,:], color=color_x)
        ax[2*i_s + 1, i_m+1].plot(time_array, controls[i_s][i_m][0,1,:], color=color_y)

        ax[2*i_s, i_m+1].text(0.04,0.1, r'$\mathcal{F} = $' + "{:.3f}".format(costs[i_s][i_m+1]),
        transform=ax[2*i_s, i_m+1].transAxes, fontsize=fs, bbox=box_props)

        wc_plot.params["x_ext"] = controls[i_s][i_m][:,0,:] + background_input_osc
        wc_plot.params["y_ext"] = controls[i_s][i_m][:,1,:]

        ax[2*i_s, i_m+1].plot(time_array[1:], target[0,0,1:], color=color_x, linewidth=1, linestyle='--')
        ax[2*i_s, i_m+1].plot(time_array[1:], target[0,1,1:], color=color_y, linewidth=1, linestyle='--')

        for m in range(10):
            wc_plot.run()
            ax[2*i_s, i_m+1].plot(time_array[1:], wc_plot.exc[0,:], color=color_x, linewidth=1)
            ax[2*i_s, i_m+1].plot(time_array[1:], wc_plot.inh[0,:], color=color_y, linewidth=1)



    for k in range(col-1):
        ax[2*i_s,k].set_yticks([])
        ax[2*i_s+1,k].set_yticks([])

    for k in range(col):
        ax[2*i_s,k].set_ylim([-0., 0.33])
        ax[2*i_s+1,k].set_ylim([-0.33, 0.24])
    
    ax[2*i_s,-1].yaxis.tick_right()
    ax[2*i_s+1,-1].yaxis.tick_right()

    ax[2*i_s,-1].set_ylabel("Activity", fontsize=fs)
    ax[2*i_s,-1].yaxis.set_label_position("right")
    ax[2*i_s+1,-1].set_ylabel("Control", fontsize=fs)
    ax[2*i_s+1,-1].yaxis.set_label_position("right")


for k in range(col):
    for j in range(row-1):
        ax[j,k].set_xticks([])
        ax[j,k].set_xlim([0,duration])
        ax[j,k].tick_params(axis='both', labelsize=fs)
    ax[-1,k].set_xticks(np.arange(0,120,20))
    ax[-1,k].set_xlim([0,duration])
    ax[-1,k].tick_params(axis='both', labelsize=fs)
    ax[-1,k].set_xlabel("Time [ms]", fontsize=fs)

for i_m in range(len(M_array)):
    ax[0,i_m+1].set_title(r"$M=$" + "{}".format(M_array[i_m]), fontsize=fs)

ax[0,0].set_title(r"Deterministic OC", fontsize=fs)

fig.savefig(os.path.join(savepath, 'wc_osc_down_traces.jpg'), bbox_inches='tight')
plt.show()

# %%
row, col = len(sigma_array), 1

fig = plt.figure(figsize=(6,5*row))
gs = fig.add_gridspec(row, col, hspace=0.1, wspace=0)
ax = gs.subplots(sharex='col')
fs = 14

for i_s in range(len(sigma_array)):
    for i_m in range(len(M_array)):
        ax[i_s].plot(costs_history[i_s][i_m], label=r'$M=$' + '{}'.format(M_array[i_m]))

    ax[i_s].hlines(costs[i_s,0], 0, max_iterations, label='DOC', linestyle='--', color='grey')

    ax[i_s].text(-0.05, 0.4, r'$\sigma = $'+ "{}".format(sigma_array[i_s]), transform=ax[i_s].transAxes, rotation='vertical', fontsize=fs)

    ax[i_s].set_ylabel(r'Total cost $\mathcal{F}$', fontsize=fs)
    ax[i_s].yaxis.set_label_position("right")
    ax[i_s].yaxis.tick_right()
    ax[i_s].tick_params(axis='both', labelsize=fs)
    ax[i_s].set_xlim([0,max_iterations])
    ax[i_s].set_yscale('log')
    ax[i_s].set_ylim(0.01, 0.03)

ax[0].legend(loc='upper right', fontsize=fs)
ax[-1].set_xlabel("Iteration", fontsize=fs)

fig.savefig(os.path.join(savepath, 'wc_osc_down_cost.jpg'), bbox_inches='tight')
plt.show()
